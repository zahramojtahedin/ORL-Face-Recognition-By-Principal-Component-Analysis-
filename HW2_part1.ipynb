# %%
import cv2
import os
import pandas as pd
from google.colab.patches import cv2_imshow
import matplotlib.pyplot as plt
import numpy as np

# Specify the root path to your dataset directory
root_path = '/content/drive/MyDrive/Colab Notebooks/ORL'

# Create a directory to save the images
output_directory = '/content/drive/MyDrive/Colab Notebooks/all_images'
os.makedirs(output_directory, exist_ok=True)

# Create an empty list to store images
all_images = []

# Loop through each directory (s1, s2, ..., s40)
for i in range(1, 41):
    # Construct the path to the current directory
    current_dir = os.path.join(root_path, f's{i}')
    # Get a list of all files in the current directory
    files = os.listdir(current_dir)

    # Loop through each file in the directory
    for file in files:
        # Construct the full file path
        file_path = os.path.join(current_dir, file)
        print(file_path)

        # Read the image using OpenCV in grayscale
        img = cv2.imread(file_path, cv2.IMREAD_GRAYSCALE)

        # Resize the image to 48x48 pixels
        img_resized = cv2.resize(img, (48, 48))

        # Save the resized image to the output directory
        output_path = os.path.join(output_directory, f's{i}_{file}')
        cv2.imwrite(output_path, img_resized)

        # Append the resized image to the list
        all_images.append(img_resized)

# Convert the list of images to a DataFrame
df = pd.DataFrame({'Image': all_images})

# Calculate the number of rows and columns for subplots
num_rows = 10
num_cols = 40

# Create a subplot with a grid layout
fig, axs = plt.subplots(num_rows, num_cols, figsize=(40, 10))

# Loop through each image and display it in a subplot
for i in range(len(all_images)):
    row = i % num_rows
    col = i // num_rows
    axs[row, col].imshow(all_images[i], cmap='gray')  # Use cmap='gray' for grayscale images
    axs[row, col].axis('off')

# Adjust layout for better display
plt.tight_layout()
plt.show()
# Out:
# /content/drive/MyDrive/Colab Notebooks/ORL/s1/7.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s1/2.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s1/1.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s1/8.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s1/9.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s1/10.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s1/6.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s1/5.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s1/3.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s1/4.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s2/9.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s2/4.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s2/8.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s2/10.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s2/6.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s2/7.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s2/5.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s2/1.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s2/2.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s2/3.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s3/10.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s3/1.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s3/9.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s3/8.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s3/5.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s3/2.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s3/7.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s3/3.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s3/4.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s3/6.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s4/5.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s4/4.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s4/2.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s4/3.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s4/1.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s4/10.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s4/9.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s4/6.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s4/8.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s4/7.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s5/5.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s5/8.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s5/9.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s5/6.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s5/7.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s5/3.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s5/2.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s5/10.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s5/1.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s5/4.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s6/9.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s6/7.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s6/8.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s6/1.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s6/10.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s6/3.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s6/2.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s6/5.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s6/4.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s6/6.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s7/4.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s7/1.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s7/2.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s7/3.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s7/10.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s7/5.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s7/8.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s7/7.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s7/9.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s7/6.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s8/7.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s8/8.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s8/9.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s8/6.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s8/5.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s8/1.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s8/10.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s8/2.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s8/3.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s8/4.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s9/6.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s9/8.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s9/9.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s9/7.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s9/5.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s9/4.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s9/10.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s9/2.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s9/1.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s9/3.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s10/6.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s10/7.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s10/8.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s10/9.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s10/3.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s10/2.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s10/10.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s10/1.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s10/5.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s10/4.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s11/7.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s11/6.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s11/5.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s11/8.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s11/9.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s11/2.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s11/1.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s11/4.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s11/10.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s11/3.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s12/4.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s12/2.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s12/3.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s12/10.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s12/1.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s12/5.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s12/6.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s12/8.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s12/9.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s12/7.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s13/8.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s13/3.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s13/4.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s13/7.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s13/6.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s13/9.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s13/5.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s13/1.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s13/2.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s13/10.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s14/6.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s14/7.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s14/8.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s14/9.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s14/3.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s14/5.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s14/4.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s14/10.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s14/2.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s14/1.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s15/10.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s15/2.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s15/1.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s15/3.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s15/4.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s15/5.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s15/9.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s15/6.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s15/7.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s15/8.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s16/6.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s16/9.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s16/2.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s16/10.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s16/1.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s16/3.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s16/4.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s16/5.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s16/8.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s16/7.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s17/3.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s17/4.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s17/2.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s17/1.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s17/10.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s17/9.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s17/5.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s17/8.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s17/6.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s17/7.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s18/2.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s18/5.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s18/9.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s18/6.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s18/8.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s18/7.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s18/4.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s18/3.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s18/10.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s18/1.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s19/9.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s19/6.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s19/1.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s19/3.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s19/10.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s19/8.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s19/7.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s19/5.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s19/4.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s19/2.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s20/3.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s20/7.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s20/8.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s20/6.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s20/4.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s20/5.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s20/9.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s20/2.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s20/10.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s20/1.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s21/4.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s21/10.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s21/8.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s21/5.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s21/3.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s21/6.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s21/7.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s21/1.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s21/2.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s21/9.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s22/10.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s22/1.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s22/2.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s22/5.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s22/3.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s22/7.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s22/8.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s22/9.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s22/4.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s22/6.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s23/9.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s23/7.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s23/8.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s23/4.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s23/5.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s23/6.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s23/3.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s23/2.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s23/1.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s23/10.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s24/10.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s24/2.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s24/1.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s24/8.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s24/6.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s24/5.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s24/3.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s24/4.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s24/7.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s24/9.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s25/5.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s25/4.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s25/3.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s25/9.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s25/7.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s25/8.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s25/6.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s25/2.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s25/1.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s25/10.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s26/5.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s26/7.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s26/3.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s26/8.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s26/4.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s26/6.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s26/9.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s26/10.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s26/1.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s26/2.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s27/1.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s27/9.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s27/7.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s27/8.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s27/5.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s27/3.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s27/6.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s27/4.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s27/2.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s27/10.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s28/9.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s28/1.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s28/10.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s28/8.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s28/6.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s28/5.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s28/3.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s28/2.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s28/7.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s28/4.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s29/9.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s29/1.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s29/10.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s29/3.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s29/7.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s29/6.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s29/2.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s29/8.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s29/5.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s29/4.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s30/8.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s30/4.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s30/10.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s30/3.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s30/2.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s30/7.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s30/6.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s30/1.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s30/9.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s30/5.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s31/1.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s31/5.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s31/7.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s31/9.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s31/10.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s31/2.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s31/3.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s31/4.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s31/6.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s31/8.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s32/7.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s32/4.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s32/10.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s32/2.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s32/3.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s32/6.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s32/5.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s32/8.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s32/9.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s32/1.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s33/4.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s33/5.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s33/3.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s33/10.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s33/2.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s33/8.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s33/7.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s33/6.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s33/9.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s33/1.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s34/7.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s34/2.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s34/10.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s34/5.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s34/3.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s34/6.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s34/4.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s34/1.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s34/8.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s34/9.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s35/9.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s35/8.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s35/5.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s35/10.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s35/4.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s35/7.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s35/1.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s35/3.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s35/2.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s35/6.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s36/7.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s36/9.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s36/8.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s36/1.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s36/4.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s36/5.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s36/2.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s36/10.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s36/3.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s36/6.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s37/2.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s37/1.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s37/5.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s37/10.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s37/4.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s37/6.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s37/8.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s37/9.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s37/7.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s37/3.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s38/9.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s38/7.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s38/8.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s38/6.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s38/4.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s38/1.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s38/5.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s38/2.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s38/3.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s38/10.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s39/7.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s39/9.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s39/3.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s39/1.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s39/4.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s39/6.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s39/2.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s39/10.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s39/8.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s39/5.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s40/8.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s40/7.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s40/2.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s40/4.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s40/5.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s40/10.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s40/1.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s40/3.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s40/6.bmp
# /content/drive/MyDrive/Colab Notebooks/ORL/s40/9.bmp

# %%
# Create empty lists for train and test data
train_data = []
test_data = []

# Number of images per subject for train and test
num_train_images = 5
num_test_images = 5

# Loop through each subject
for i in range(1, 41):
    # Extract images for train data
    train_images = all_images[(i - 1) * 10 : (i - 1) * 10 + num_train_images]
    train_data.extend(train_images)

    # Extract images for test data
    test_images = all_images[(i - 1) * 10 + num_train_images : i * 10]
    test_data.extend(test_images)

# Convert train and test data to DataFrames
df_train = pd.DataFrame({'Image': train_data})
df_test = pd.DataFrame({'Image': test_data})

num_images_to_plot = 40

# Plot the first 40 images
fig, axes = plt.subplots(4, 10, figsize=(15, 6), subplot_kw={'xticks':[], 'yticks':[]})

for i, ax in enumerate(axes.flat):
    ax.imshow(train_data[i], cmap='gray')  # Assuming images are grayscale
    ax.set_title(f"Image {i+1}")

plt.show()

# Number of subjects
num_subjects = 40

# Number of images per subject for train and test
num_train_images = 5
num_test_images = 5

# Create Y_train and Y_test arrays
Y_train = np.repeat(np.arange(1, num_subjects + 1), num_train_images)
Y_test = np.repeat(np.arange(1, num_subjects + 1), num_test_images)

# Verify the shapes
print("Y_train shape:", Y_train.shape)
print("Y_test shape:", Y_test.shape)
# Out:
# Y_train shape: (200,)
# Y_test shape: (200,)

# %%
image_shape = all_images[0].shape
print("Shape of each image:", image_shape)
# Out:
# Shape of each image: (48, 48)

# %%
import numpy as np

# Function to flatten each image to a vector
def flatten_image(image):
    return image.flatten()

# Apply the flatten_image function to each image in train_data and test_data
train_vectors = [flatten_image(image) for image in train_data]
test_vectors = [flatten_image(image) for image in test_data]

# Convert the lists of vectors to NumPy arrays
x_train_reshaped = np.array(train_vectors)
x_test_reshaped = np.array(test_vectors)

# %%
#calculate the covariance matrix and the eigenvalue and eigenvectors of the covariance matrix.
covariance = np.cov(x_train_reshaped.T)

# %%
explained_variance = 0.87
U, S, Vh = np.linalg.svd(covariance, full_matrices=True)
#calculate the total variance from eigenvalues and find the first k component that contains the eplained_variance of the total variance.
NormSumOfS = np.cumsum(S)/np.sum(S)
index = np.argmax(NormSumOfS > explained_variance)
V = Vh.T

# %%
# here show 50 first of this images
def show_images(num_images,X):
    #inputs dataset and number of images wants to show
    #output plot images
    plt.figure(figsize=(10, 5))
    for i in range(num_images):
        plt.subplot(5, 10, i + 1)
        plt.imshow(X[i] / 255.0, cmap='gray')
        plt.axis('off')
    plt.show()
#Project Images into Reduced Dimensionality Eigenbasis F=X*V (X is our dataset,F our reduced dimensionality dataset,V is k choosen eigenvectors)
#And Reproject Images to Standard Basis for plotting the reduced component image X_k=F*V_transpose (V_transpose is equal to V inverse)
#select one sample and reshape it to a 28 by 28 matrix and plot them as image
F = np.dot(np.dot(x_train_reshaped,V[:, :index]), V[:, :index].T)
#plot the dimentionally reduced data
#plot the original data
F_reshaped = F.reshape(200, 48, 48)
show_images(1,F_reshaped)
show_images(1,train_data)

# %%
from sklearn.decomposition import PCA

def do_pca(n_components, data, data1):
    # Create a PCA instance with the desired number of components
    pca = PCA(n_components=n_components)

    # Fit the PCA model to your data and transform the data
    projected_data = pca.fit_transform(data)
    projected_data1 = pca.transform(data1)
    return projected_data, projected_data1


import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.ensemble import RandomForestClassifier

def plot_confusion_matrix(Y_test, Y_pred):
    cm = confusion_matrix(Y_test, Y_pred)
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=['Predicted 0', 'Predicted 1'], yticklabels=['Actual 0', 'Actual 1'])
    plt.xlabel('Predicted Label')
    plt.ylabel('True Label')
    plt.title('Confusion Matrix')
    plt.show()

from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score, ConfusionMatrixDisplay

def ML_model(X_train, X_test, Y_train, Y_test, print_output=True, pc=1, plot_conf=False):
    # Configure MLP classifier with Adam optimizer and 0.01 learning rate
    model = MLPClassifier(solver='adam', learning_rate_init=0.01, max_iter=300)  # Adjust max_iter if needed

    # Fit the model on the training data
    model.fit(X_train, Y_train)

    # Make predictions on the test data
    Y_pred = model.predict(X_test)

    # Calculate the accuracy of the model
    acc = accuracy_score(Y_test, Y_pred)

    if print_output:
        print(f"Accuracy: {acc * 100:.2f}%")
        print(f"PC Components: {pc}")
        
    if plot_conf:
        # Plot confusion matrix
        ConfusionMatrixDisplay.from_predictions(Y_test, Y_pred)

    return acc

# %%
import matplotlib.pyplot as plt

# Initialize lists to store accuracy and number of components
acc_list, pc_list = [], []

for pc in range(2, 70):
    # Perform PCA with the current number of components
    projected_train_data, projected_test_data = do_pca(pc, x_train_reshaped, x_test_reshaped)

    # Train the SVM model and calculate accuracy
    accuracy = ML_model(projected_train_data, projected_test_data, Y_train, Y_test, True, pc)

    # Append the accuracy and number of components to the lists
    acc_list.append(accuracy)
    pc_list.append(pc)
# Out:
# Accuracy: 23.50%
# PC Components: 2
# Accuracy: 39.00%
# PC Components: 3
# Accuracy: 52.50%
# PC Components: 4
# Accuracy: 57.00%
# PC Components: 5
# Accuracy: 66.50%
# PC Components: 6
# Accuracy: 73.00%
# PC Components: 7
# Accuracy: 80.50%
# PC Components: 8
# Accuracy: 79.50%
# PC Components: 9
# Accuracy: 75.50%
# PC Components: 10
# Accuracy: 81.00%
# PC Components: 11
# Accuracy: 83.00%
# PC Components: 12
# Accuracy: 85.00%
# PC Components: 13
# Accuracy: 85.00%
# PC Components: 14
# Accuracy: 88.00%
# PC Components: 15
# Accuracy: 86.00%
# PC Components: 16
# Accuracy: 91.50%
# PC Components: 17
# Accuracy: 86.50%
# PC Components: 18
# Accuracy: 85.50%
# PC Components: 19
# Accuracy: 90.00%
# PC Components: 20
# Accuracy: 90.50%
# PC Components: 21
# Accuracy: 87.50%
# PC Components: 22
# Accuracy: 87.50%
# PC Components: 23
# Accuracy: 87.50%
# PC Components: 24
# Accuracy: 90.50%
# PC Components: 25
# Accuracy: 89.50%
# PC Components: 26
# Accuracy: 88.00%
# PC Components: 27
# Accuracy: 89.00%
# PC Components: 28
# Accuracy: 86.50%
# PC Components: 29
# Accuracy: 89.50%
# PC Components: 30
# Accuracy: 86.00%
# PC Components: 31
# Accuracy: 89.50%
# PC Components: 32
# Accuracy: 89.50%
# PC Components: 33
# Accuracy: 91.50%
# PC Components: 34
# Accuracy: 89.50%
# PC Components: 35
# Accuracy: 87.50%
# PC Components: 36
# Accuracy: 88.00%
# PC Components: 37
# Accuracy: 89.00%
# PC Components: 38
# Accuracy: 89.50%
# PC Components: 39
# Accuracy: 89.00%
# PC Components: 40
# Accuracy: 88.00%
# PC Components: 41
# Accuracy: 87.50%
# PC Components: 42
# Accuracy: 90.50%
# PC Components: 43
# Accuracy: 86.50%
# PC Components: 44
# Accuracy: 90.00%
# PC Components: 45
# Accuracy: 91.00%
# PC Components: 46
# Accuracy: 88.00%
# PC Components: 47
# Accuracy: 85.50%
# PC Components: 48
# Accuracy: 90.00%
# PC Components: 49
# Accuracy: 85.50%
# PC Components: 50
# Accuracy: 90.50%
# PC Components: 51
# Accuracy: 90.50%
# PC Components: 52
# Accuracy: 89.00%
# PC Components: 53
# Accuracy: 90.00%
# PC Components: 54
# Accuracy: 90.00%
# PC Components: 55
# Accuracy: 87.00%
# PC Components: 56
# Accuracy: 86.50%
# PC Components: 57
# Accuracy: 88.00%
# PC Components: 58
# Accuracy: 88.50%
# PC Components: 59
# Accuracy: 88.50%
# PC Components: 60
# Accuracy: 91.50%
# PC Components: 61
# Accuracy: 89.50%
# PC Components: 62
# Accuracy: 89.00%
# PC Components: 63
# Accuracy: 84.50%
# PC Components: 64
# Accuracy: 86.50%
# PC Components: 65
# Accuracy: 89.50%
# PC Components: 66
# Accuracy: 84.50%
# PC Components: 67
# Accuracy: 87.50%
# PC Components: 68
# Accuracy: 89.50%
# PC Components: 69

# %%
# Plot the accuracy vs. number of components
plt.figure(figsize=(10, 6))
plt.plot(pc_list, acc_list, marker='o', linestyle='-')
plt.title('Accuracy vs. Number of Components')
plt.xlabel('Number of Components')
plt.ylabel('Accuracy')
plt.grid(True)
plt.show()

# %%
# Find the index of the maximum accuracy in the acc_list
best_acc_index = acc_list.index(max(acc_list))

# Get the corresponding number of components for the best accuracy
best_pc = pc_list[best_acc_index]

print("Number of components for the best model:", best_pc)
# Out:
# Number of components for the best model: 17

# %%
# Perform PCA with the current number of components
projected_train_data, projected_test_data = do_pca(pc, x_train_reshaped, x_test_reshaped)

# Train the SVM model and calculate accuracy
accuracy = ML_model(projected_train_data, projected_test_data, Y_train, Y_test, True, best_pc, True)
# Out:
# Accuracy: 87.50%
# PC Components: 17

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.decomposition import PCA
from sklearn.feature_selection import SelectKBest, mutual_info_classif


def select_features_after_pca(n_components, data, data1, k):
    # Create a PCA instance with the desired number of components
    pca = PCA(n_components=n_components)

    # Fit the PCA model to your data and transform the data
    projected_data = pca.fit_transform(data)
    projected_data1 = pca.transform(data1)

    # Train a RandomForestClassifier on the reduced data to obtain feature importances
    model = RandomForestClassifier(n_estimators=100)
    model.fit(projected_data, Y_train)

    # Get feature importances
    feature_importances = model.feature_importances_

    # Rank features based on importance
    ranked_features = np.argsort(feature_importances)[::-1]

    # Select the top-k features using Information Gain
    k_best = SelectKBest(mutual_info_classif, k=k)
    selected_data = k_best.fit_transform(projected_data, Y_train)
    selected_data1 = k_best.transform(projected_data1)

    return selected_data, selected_data1

# ... (The rest of your code remains unchanged)

# Initialize lists to store accuracy and number of components
acc_list, pc_list = [], []

# Specify the number of features (k) to select after PCA
k_features = 20  # You can adjust this based on your requirements

for pc in range(5, 70):
    # Perform PCA with the current number of components and select features
    selected_train_data, selected_test_data = select_features_after_pca(pc, x_train_reshaped, x_test_reshaped, int(round(pc / 2)))

    # Train the SVM model and calculate accuracy
    accuracy = ML_model(selected_train_data, selected_test_data, Y_train, Y_test, True, pc)

    # Append the accuracy and number of components to the lists
    acc_list.append(accuracy)
    pc_list.append(pc)

# Plot the accuracy vs. number of components
plt.figure(figsize=(10, 6))
plt.plot(pc_list, acc_list, marker='o', linestyle='-')
plt.title('Accuracy vs. Number of Components with Feature Selection(Information Gain), # of features = round(pc / 2)')
plt.xlabel('Number of Components')
plt.ylabel('Accuracy')
plt.grid(True)
plt.show()
# Find the index of the maximum accuracy in the acc_list
best_acc_index = acc_list.index(max(acc_list))

# Get the corresponding number of components for the best accuracy
best_pc = pc_list[best_acc_index]

# Perform PCA with the current number of components
projected_train_data, projected_test_data = select_features_after_pca(pc, x_train_reshaped, x_test_reshaped, int(round(best_pc / 2)))

# Train the SVM model and calculate accuracy
accuracy = ML_model(projected_train_data, projected_test_data, Y_train, Y_test, True, best_pc, True)
# Out:
# Accuracy: 28.00%
# PC Components: 5
# Accuracy: 42.50%
# PC Components: 6
# Accuracy: 53.00%
# PC Components: 7
# Accuracy: 57.00%
# PC Components: 8
# Accuracy: 57.00%
# PC Components: 9
# Accuracy: 62.50%
# PC Components: 10
# Accuracy: 71.50%
# PC Components: 11
# Accuracy: 67.00%
# PC Components: 12
# Accuracy: 68.50%
# PC Components: 13
# Accuracy: 72.00%
# PC Components: 14
# Accuracy: 80.00%
# PC Components: 15
# Accuracy: 79.00%
# PC Components: 16
# Accuracy: 77.50%
# PC Components: 17
# Accuracy: 81.00%
# PC Components: 18
# Accuracy: 83.50%
# PC Components: 19
# Accuracy: 85.50%
# PC Components: 20
# Accuracy: 81.50%
# PC Components: 21
# Accuracy: 85.50%
# PC Components: 22
# Accuracy: 85.00%
# PC Components: 23
# Accuracy: 80.00%
# PC Components: 24
# Accuracy: 85.00%
# PC Components: 25
# Accuracy: 87.00%
# PC Components: 26
# Accuracy: 88.00%
# PC Components: 27
# Accuracy: 84.50%
# PC Components: 28
# Accuracy: 88.00%
# PC Components: 29
# Accuracy: 91.00%
# PC Components: 30
# Accuracy: 88.50%
# PC Components: 31
# Accuracy: 86.00%
# PC Components: 32
# Accuracy: 88.50%
# PC Components: 33
# Accuracy: 90.50%
# PC Components: 34
# Accuracy: 85.50%
# PC Components: 35
# Accuracy: 84.50%
# PC Components: 36
# Accuracy: 89.00%
# PC Components: 37
# Accuracy: 86.50%
# PC Components: 38
# Accuracy: 87.00%
# PC Components: 39
# Accuracy: 89.00%
# PC Components: 40
# Accuracy: 91.50%
# PC Components: 41
# Accuracy: 87.50%
# PC Components: 42
# Accuracy: 88.00%
# PC Components: 43
# Accuracy: 87.00%
# PC Components: 44
# Accuracy: 88.50%
# PC Components: 45
# Accuracy: 89.50%
# PC Components: 46
# Accuracy: 87.00%
# PC Components: 47
# Accuracy: 89.00%
# PC Components: 48
# Accuracy: 89.00%
# PC Components: 49
# Accuracy: 88.50%
# PC Components: 50
# Accuracy: 87.00%
# PC Components: 51
# Accuracy: 88.50%
# PC Components: 52
# Accuracy: 88.50%
# PC Components: 53
# Accuracy: 90.50%
# PC Components: 54
# Accuracy: 88.50%
# PC Components: 55
# Accuracy: 90.00%
# PC Components: 56
# Accuracy: 89.50%
# PC Components: 57
# Accuracy: 90.00%
# PC Components: 58
# Accuracy: 88.00%
# PC Components: 59
# Accuracy: 88.50%
# PC Components: 60
# Accuracy: 87.00%
# PC Components: 61
# Accuracy: 90.00%
# PC Components: 62
# Accuracy: 87.00%
# PC Components: 63
# Accuracy: 89.50%
# PC Components: 64
# Accuracy: 88.50%
# PC Components: 65
# Accuracy: 90.00%
# PC Components: 66
# Accuracy: 87.50%
# PC Components: 67
# Accuracy: 89.00%
# PC Components: 68
# Accuracy: 90.00%
# PC Components: 69
# Accuracy: 88.00%
# PC Components: 41

# %%
# !pip install skfeature-chappers

import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.decomposition import PCA
from sklearn.feature_selection import SelectKBest
from skfeature.function.similarity_based import fisher_score

def select_features_after_pca2(n_components, data, data1, k):
    # Create a PCA instance with the desired number of components
    pca = PCA(n_components=n_components)

    # Fit the PCA model to your data and transform the data
    projected_data = pca.fit_transform(data)
    projected_data1 = pca.transform(data1)

    # Train a RandomForestClassifier on the reduced data to obtain feature importances
    model = RandomForestClassifier(n_estimators=100)
    model.fit(projected_data, Y_train)

    # Get feature importances
    feature_importances = model.feature_importances_

    # Rank features based on importance
    ranked_features = np.argsort(feature_importances)[::-1]

    # Select the top-k features using Fisher's Score
    score = fisher_score.fisher_score(projected_data, Y_train)
    ranked_features_fisher = np.argsort(score)[::-1]
    selected_data = projected_data[:, ranked_features_fisher[:k]]
    selected_data1 = projected_data1[:, ranked_features_fisher[:k]]

    return selected_data, selected_data1

# ... (The rest of your code remains unchanged)

# Initialize lists to store accuracy and number of components
acc_list, pc_list = [], []

# Specify the number of features (k) to select after PCA
k_features = 20  # You can adjust this based on your requirements

for pc in range(5, 70):
    # Perform PCA with the current number of components and select features
    selected_train_data, selected_test_data = select_features_after_pca2(pc, x_train_reshaped, x_test_reshaped, int(round(pc / 2)))

    # Train the SVM model and calculate accuracy
    accuracy = ML_model(selected_train_data, selected_test_data, Y_train, Y_test, True, pc)

    # Append the accuracy and number of components to the lists
    acc_list.append(accuracy)
    pc_list.append(pc)

# Plot the accuracy vs. number of components
plt.figure(figsize=(10, 6))
plt.plot(pc_list, acc_list, marker='o', linestyle='-')
plt.title('Accuracy vs. Number of Components with Feature Selection(Fisher Score), # of features = round(pc / 2)')
plt.xlabel('Number of Components')
plt.ylabel('Accuracy')
plt.grid(True)
plt.show()
# Find the index of the maximum accuracy in the acc_list
best_acc_index = acc_list.index(max(acc_list))

# Get the corresponding number of components for the best accuracy
best_pc = pc_list[best_acc_index]

# Perform PCA with the current number of components
projected_train_data, projected_test_data = select_features_after_pca2(pc, x_train_reshaped, x_test_reshaped, int(round(best_pc / 2)))

# Train the SVM model and calculate accuracy
accuracy = ML_model(projected_train_data, projected_test_data, Y_train, Y_test, True, best_pc, True)
# Out:
# Collecting skfeature-chappers
#   Downloading skfeature_chappers-1.1.0-py3-none-any.whl.metadata (926 bytes)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from skfeature-chappers) (1.5.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from skfeature-chappers) (2.2.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from skfeature-chappers) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->skfeature-chappers) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->skfeature-chappers) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->skfeature-chappers) (2024.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->skfeature-chappers) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->skfeature-chappers) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->skfeature-chappers) (3.5.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->skfeature-chappers) (1.16.0)
# Downloading skfeature_chappers-1.1.0-py3-none-any.whl (66 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.3/66.3 kB 3.4 MB/s eta 0:00:00
# Installing collected packages: skfeature-chappers
# Successfully installed skfeature-chappers-1.1.0
# Accuracy: 19.50%
# PC Components: 5
# Accuracy: 36.00%
# PC Components: 6
# Accuracy: 51.00%
# PC Components: 7
# Accuracy: 44.00%
# PC Components: 8
# Accuracy: 43.50%
# PC Components: 9
# Accuracy: 56.00%
# PC Components: 10
# Accuracy: 65.50%
# PC Components: 11
# Accuracy: 65.00%
# PC Components: 12
# Accuracy: 64.00%
# PC Components: 13
# Accuracy: 71.50%
# PC Components: 14
# Accuracy: 74.00%
# PC Components: 15
# Accuracy: 73.00%
# PC Components: 16
# Accuracy: 74.00%
# PC Components: 17
# Accuracy: 74.50%
# PC Components: 18
# Accuracy: 78.50%
# PC Components: 19
# Accuracy: 77.50%
# PC Components: 20
# Accuracy: 80.50%
# PC Components: 21
# Accuracy: 81.50%
# PC Components: 22
# Accuracy: 78.50%
# PC Components: 23
# Accuracy: 78.50%
# PC Components: 24
# Accuracy: 78.50%
# PC Components: 25
# Accuracy: 84.50%
# PC Components: 26
# Accuracy: 86.00%
# PC Components: 27
# Accuracy: 79.50%
# PC Components: 28
# Accuracy: 80.50%
# PC Components: 29
# Accuracy: 81.50%
# PC Components: 30
# Accuracy: 84.50%
# PC Components: 31
# Accuracy: 85.50%
# PC Components: 32
# Accuracy: 82.50%
# PC Components: 33
# Accuracy: 88.00%
# PC Components: 34
# Accuracy: 86.50%
# PC Components: 35
# Accuracy: 86.00%
# PC Components: 36
# Accuracy: 86.50%
# PC Components: 37
# Accuracy: 88.00%
# PC Components: 38
# Accuracy: 86.50%
# PC Components: 39
# Accuracy: 85.00%
# PC Components: 40
# Accuracy: 87.00%
# PC Components: 41
# Accuracy: 90.00%
# PC Components: 42
# Accuracy: 89.50%
# PC Components: 43
# Accuracy: 86.00%
# PC Components: 44
# Accuracy: 84.50%
# PC Components: 45
# Accuracy: 90.00%
# PC Components: 46
# Accuracy: 90.00%
# PC Components: 47
# Accuracy: 88.50%
# PC Components: 48
# Accuracy: 90.50%
# PC Components: 49
# Accuracy: 87.00%
# PC Components: 50
# Accuracy: 89.50%
# PC Components: 51
# Accuracy: 89.50%
# PC Components: 52
# Accuracy: 88.00%
# PC Components: 53
# Accuracy: 90.50%
# PC Components: 54
# Accuracy: 89.50%
# PC Components: 55
# Accuracy: 90.50%
# PC Components: 56
# Accuracy: 88.50%
# PC Components: 57
# Accuracy: 89.00%
# PC Components: 58
# Accuracy: 90.00%
# PC Components: 59
# Accuracy: 88.00%
# PC Components: 60
# Accuracy: 86.00%
# PC Components: 61
# Accuracy: 88.50%
# PC Components: 62
# Accuracy: 87.50%
# PC Components: 63
# Accuracy: 86.00%
# PC Components: 64
# Accuracy: 88.00%
# PC Components: 65
# Accuracy: 88.00%
# PC Components: 66
# Accuracy: 87.00%
# PC Components: 67
# Accuracy: 89.00%
# PC Components: 68
# Accuracy: 89.00%
# PC Components: 69
# Accuracy: 88.50%
# PC Components: 49

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.decomposition import PCA
from scipy.stats import pearsonr

def select_features_after_pca3(n_components, data, data1, k):
    # Create a PCA instance with the desired number of components
    pca = PCA(n_components=n_components)

    # Fit the PCA model to your data and transform the data
    projected_data = pca.fit_transform(data)
    projected_data1 = pca.transform(data1)

    # Train a RandomForestClassifier on the reduced data to obtain feature importances
    model = RandomForestClassifier(n_estimators=100)
    model.fit(projected_data, Y_train)

    # Get feature importances
    feature_importances = model.feature_importances_

    # Rank features based on importance
    ranked_features = np.argsort(feature_importances)[::-1]

    # Calculate the Pearson correlation coefficients between features and target (Y_train)
    correlation_coefficients = [pearsonr(projected_data[:, i], Y_train)[0] for i in range(projected_data.shape[1])]

    # Rank features based on absolute correlation coefficients
    ranked_features_correlation = np.argsort(np.abs(correlation_coefficients))[::-1]

    # Select the top-k features using Correlation Coefficient
    selected_data = projected_data[:, ranked_features_correlation[:k]]
    selected_data1 = projected_data1[:, ranked_features_correlation[:k]]

    return selected_data, selected_data1

# ... (The rest of your code remains unchanged)

# Initialize lists to store accuracy and number of components
acc_list, pc_list = [], []

# Specify the number of features (k) to select after PCA
k_features = 20  # You can adjust this based on your requirements

for pc in range(5, 70):
    # Perform PCA with the current number of components and select features
    selected_train_data, selected_test_data = select_features_after_pca3(pc, x_train_reshaped, x_test_reshaped, int(round(pc / 2)))

    # Train the SVM model and calculate accuracy
    accuracy = ML_model(selected_train_data, selected_test_data, Y_train, Y_test, True, pc)

    # Append the accuracy and number of components to the lists
    acc_list.append(accuracy)
    pc_list.append(pc)

# Plot the accuracy vs. number of components
plt.figure(figsize=(10, 6))
plt.plot(pc_list, acc_list, marker='o', linestyle='-')
plt.title('Accuracy vs. Number of Components with Feature Selection(Correlation Coeff), # of features = round(pc / 2)')
plt.xlabel('Number of Components')
plt.ylabel('Accuracy')
plt.grid(True)
plt.show()
# Find the index of the maximum accuracy in the acc_list
best_acc_index = acc_list.index(max(acc_list))

# Get the corresponding number of components for the best accuracy
best_pc = pc_list[best_acc_index]

# Perform PCA with the current number of components
projected_train_data, projected_test_data = select_features_after_pca3(pc, x_train_reshaped, x_test_reshaped, int(round(best_pc / 2)))

# Train the SVM model and calculate accuracy
accuracy = ML_model(projected_train_data, projected_test_data, Y_train, Y_test, True, best_pc, True)
# Out:
# Accuracy: 23.00%
# PC Components: 5
# Accuracy: 38.50%
# PC Components: 6
# Accuracy: 52.50%
# PC Components: 7
# Accuracy: 50.50%
# PC Components: 8
# Accuracy: 49.00%
# PC Components: 9
# Accuracy: 54.50%
# PC Components: 10
# Accuracy: 64.00%
# PC Components: 11
# Accuracy: 62.00%
# PC Components: 12
# Accuracy: 56.00%
# PC Components: 13
# Accuracy: 61.50%
# PC Components: 14
# Accuracy: 65.50%
# PC Components: 15
# Accuracy: 61.00%
# PC Components: 16
# Accuracy: 60.50%
# PC Components: 17
# Accuracy: 64.00%
# PC Components: 18
# Accuracy: 74.00%
# PC Components: 19
# Accuracy: 65.50%
# PC Components: 20
# Accuracy: 68.00%
# PC Components: 21
# Accuracy: 76.50%
# PC Components: 22
# Accuracy: 73.50%
# PC Components: 23
# Accuracy: 74.00%
# PC Components: 24
# Accuracy: 74.50%
# PC Components: 25
# Accuracy: 76.50%
# PC Components: 26
# Accuracy: 74.50%
# PC Components: 27
# Accuracy: 79.50%
# PC Components: 28
# Accuracy: 75.50%
# PC Components: 29
# Accuracy: 74.50%
# PC Components: 30
# Accuracy: 79.50%
# PC Components: 31
# Accuracy: 77.00%
# PC Components: 32
# Accuracy: 77.50%
# PC Components: 33
# Accuracy: 78.50%
# PC Components: 34
# Accuracy: 77.50%
# PC Components: 35
# Accuracy: 81.50%
# PC Components: 36
# Accuracy: 80.00%
# PC Components: 37
# Accuracy: 81.50%
# PC Components: 38
# Accuracy: 81.00%
# PC Components: 39
# Accuracy: 78.50%
# PC Components: 40
# Accuracy: 80.50%
# PC Components: 41
# Accuracy: 84.50%
# PC Components: 42
# Accuracy: 82.00%
# PC Components: 43
# Accuracy: 84.50%
# PC Components: 44
# Accuracy: 81.50%
# PC Components: 45
# Accuracy: 86.00%
# PC Components: 46
# Accuracy: 85.50%
# PC Components: 47
# Accuracy: 84.00%
# PC Components: 48
# Accuracy: 83.00%
# PC Components: 49
# Accuracy: 86.50%
# PC Components: 50
# Accuracy: 85.50%
# PC Components: 51
# Accuracy: 85.50%
# PC Components: 52
# Accuracy: 83.50%
# PC Components: 53
# Accuracy: 83.50%
# PC Components: 54
# Accuracy: 86.00%
# PC Components: 55
# Accuracy: 86.50%
# PC Components: 56
# Accuracy: 86.00%
# PC Components: 57
# Accuracy: 85.00%
# PC Components: 58
# Accuracy: 83.50%
# PC Components: 59
# Accuracy: 84.00%
# PC Components: 60
# Accuracy: 85.00%
# PC Components: 61
# Accuracy: 85.00%
# PC Components: 62
# Accuracy: 86.00%
# PC Components: 63
# Accuracy: 82.50%
# PC Components: 64
# Accuracy: 85.50%
# PC Components: 65
# Accuracy: 84.00%
# PC Components: 66
# Accuracy: 84.50%
# PC Components: 67
# Accuracy: 84.00%
# PC Components: 68
# Accuracy: 81.50%
# PC Components: 69
# Accuracy: 77.50%
# PC Components: 50

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.decomposition import PCA
from sklearn.feature_selection import VarianceThreshold

def select_features_after_pca4(n_components, data, data1, k, variance_threshold=0.1):
    # Create a PCA instance with the desired number of components
    pca = PCA(n_components=n_components)

    # Fit the PCA model to your data and transform the data
    projected_data = pca.fit_transform(data)
    projected_data1 = pca.transform(data1)

    # Train a RandomForestClassifier on the reduced data to obtain feature importances
    model = RandomForestClassifier(n_estimators=100)
    model.fit(projected_data, Y_train)

    # Get feature importances
    feature_importances = model.feature_importances_

    # Rank features based on importance
    ranked_features = np.argsort(feature_importances)[::-1]

    # Apply Variance Threshold to select features
    selector = VarianceThreshold(threshold=variance_threshold)
    selected_data = selector.fit_transform(projected_data)
    selected_data1 = selector.transform(projected_data1)

    # If you want to keep the top-k features after applying Variance Threshold
    if k is not None:
        top_k_indices = np.argsort(feature_importances)[::-1][:k]
        selected_data = selected_data[:, top_k_indices]
        selected_data1 = selected_data1[:, top_k_indices]

    return selected_data, selected_data1

# ... (The rest of your code remains unchanged)
# Initialize lists to store accuracy and number of components
acc_list, pc_list = [], []

# Specify the number of features (k) to select after PCA
k_features = 20  # You can adjust this based on your requirements

for pc in range(5, 70):
    # Perform PCA with the current number of components and select features
    selected_train_data, selected_test_data = select_features_after_pca4(pc, x_train_reshaped, x_test_reshaped, int(round(pc / 2)))

    # Train the SVM model and calculate accuracy
    accuracy = ML_model(selected_train_data, selected_test_data, Y_train, Y_test, True, pc)

    # Append the accuracy and number of components to the lists
    acc_list.append(accuracy)
    pc_list.append(pc)

# Plot the accuracy vs. number of components
plt.figure(figsize=(10, 6))
plt.plot(pc_list, acc_list, marker='o', linestyle='-')
plt.title('Accuracy vs. Number of Components with Feature Selection(Variance Threshold), # of features = round(pc / 2)')
plt.xlabel('Number of Components')
plt.ylabel('Accuracy')
plt.grid(True)
plt.show()
# Find the index of the maximum accuracy in the acc_list
best_acc_index = acc_list.index(max(acc_list))

# Get the corresponding number of components for the best accuracy
best_pc = pc_list[best_acc_index]

# Perform PCA with the current number of components
projected_train_data, projected_test_data = select_features_after_pca4(pc, x_train_reshaped, x_test_reshaped, int(round(best_pc / 2)))

# Train the SVM model and calculate accuracy
accuracy = ML_model(projected_train_data, projected_test_data, Y_train, Y_test, True, best_pc, True)
# Out:
# Accuracy: 29.50%
# PC Components: 5
# Accuracy: 45.00%
# PC Components: 6
# Accuracy: 53.00%
# PC Components: 7
# Accuracy: 59.50%
# PC Components: 8
# Accuracy: 55.50%
# PC Components: 9
# Accuracy: 62.00%
# PC Components: 10
# Accuracy: 66.00%
# PC Components: 11
# Accuracy: 68.50%
# PC Components: 12
# Accuracy: 67.50%
# PC Components: 13
# Accuracy: 69.50%
# PC Components: 14
# Accuracy: 79.00%
# PC Components: 15
# Accuracy: 78.00%
# PC Components: 16
# Accuracy: 78.00%
# PC Components: 17
# Accuracy: 84.50%
# PC Components: 18
# Accuracy: 79.00%
# PC Components: 19
# Accuracy: 83.50%
# PC Components: 20
# Accuracy: 83.00%
# PC Components: 21
# Accuracy: 85.00%
# PC Components: 22
# Accuracy: 84.00%
# PC Components: 23
# Accuracy: 87.50%
# PC Components: 24
# Accuracy: 85.00%
# PC Components: 25
# Accuracy: 85.00%
# PC Components: 26
# Accuracy: 87.50%
# PC Components: 27
# Accuracy: 88.00%
# PC Components: 28
# Accuracy: 89.00%
# PC Components: 29
# Accuracy: 86.50%
# PC Components: 30
# Accuracy: 88.00%
# PC Components: 31
# Accuracy: 86.00%
# PC Components: 32
# Accuracy: 85.50%
# PC Components: 33
# Accuracy: 88.00%
# PC Components: 34
# Accuracy: 87.50%
# PC Components: 35
# Accuracy: 86.50%
# PC Components: 36
# Accuracy: 87.50%
# PC Components: 37
# Accuracy: 90.50%
# PC Components: 38
# Accuracy: 86.00%
# PC Components: 39
# Accuracy: 86.00%
# PC Components: 40
# Accuracy: 89.00%
# PC Components: 41
# Accuracy: 85.50%
# PC Components: 42
# Accuracy: 86.00%
# PC Components: 43
# Accuracy: 90.00%
# PC Components: 44
# Accuracy: 88.50%
# PC Components: 45
# Accuracy: 86.00%
# PC Components: 46
# Accuracy: 90.50%
# PC Components: 47
# Accuracy: 89.00%
# PC Components: 48
# Accuracy: 89.00%
# PC Components: 49
# Accuracy: 88.50%
# PC Components: 50
# Accuracy: 86.50%
# PC Components: 51
# Accuracy: 89.00%
# PC Components: 52
# Accuracy: 88.00%
# PC Components: 53
# Accuracy: 91.00%
# PC Components: 54
# Accuracy: 87.00%
# PC Components: 55
# Accuracy: 86.50%
# PC Components: 56
# Accuracy: 90.50%
# PC Components: 57
# Accuracy: 88.50%
# PC Components: 58
# Accuracy: 88.50%
# PC Components: 59
# Accuracy: 88.50%
# PC Components: 60
# Accuracy: 86.00%
# PC Components: 61
# Accuracy: 83.50%
# PC Components: 62
# Accuracy: 87.50%
# PC Components: 63
# Accuracy: 92.00%
# PC Components: 64
# Accuracy: 86.50%
# PC Components: 65
# Accuracy: 89.50%
# PC Components: 66
# Accuracy: 90.50%
# PC Components: 67
# Accuracy: 86.50%
# PC Components: 68
# Accuracy: 87.00%
# PC Components: 69
# Accuracy: 87.00%
# PC Components: 64
